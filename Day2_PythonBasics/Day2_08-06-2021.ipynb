# %% [markdown]
# ![logo.png](logo.png)
#
# ![py.jpg](attachment:py.jpg)
# # Day Objectives:
#
# - Hello World...!
#
# - Checking your python version
# - comments
# - Variable  creation
#     - A variable in programming is used to store the values/data
#     - single variable assignment
#     - Multi variable assignment
#
# - Indentation
#
# **Data Types**
#
#
#     Text Type:	str
#     Numeric Types:	int, float, complex
#     Sequence Types:	list, tuple, range
#     Mapping Type:	dict
#     Set Types:	set, frozenset
#     Boolean Type:	bool
#     Range
#
#
# - Type Casting
# - ord , chr
# - Dynamic Input Reading
#
# **Operators**
#
#     A. Arithmetic Operators ( +,-,%,/,//,*)
#
#     B. Assignment Operators ( =, +=, -=, *=, %=, /=, //=)
#
#     C. Comparison operators ( ==, >=, <=, !=, >, < )
#
#     D. Logical operators ( and, or, not )
#
#     E. Bitwise Operators ( &, |, ~, ^, >>, <<)
#
#     F. Identity Operators ( is , is not )
#
#     G. Membership Operators ( in , not in )
# - Number conversion
# - Dir,help,?
# - Conditional Statements
#     - if
#     - elif
#     - else

# %% [markdown]
# ## Task:
# - Write a program to check wheather the user eligible for vote or not
# - Check the given number is positive or negative
# - check the given number is even or odd if it's even check which is divisible by 4 or not
# - write a program to print student grade based on persentage like Distinction,pass or fail
# - Check the given year is Leap or not

# %%
# print
print("Hello SRM.. Students...!")
# Out:
# Hello SRM.. Students...!

# %%
import sys
sys.version
# Out:
# '3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]'

# %%
# single line comments
# hi guys 
# a = 1000

# %%
# djghjf
# jdfgjh
# kkfdhjg
# kfdhsgjk
# dfjshgjk

# %%
s = """hdgj
dsahgjk
ahgjk
dhjgfjk"""
type(s)
# Out:
# str

# %% [markdown]
# ### Variable Creation
# - to hold any type of dta
# - it stores given value
# - Where we can store data
# - We can give any value to variable
# - lateral values to store the data types

# %%
var = 1000

# %%
a = 10.90

# %%
s = "string"

# %%
c = 90+78j

# %% [markdown]
# ### Features of variable
# do's
# ----
# - alpha
# - _
# - alpha_
# - alpha+number
#
#
# don't
# -----
# - special char
# - space
# - we cannot give space between variable names like v 1
# - digits

# %%
v = 10

# %%
v_ = 10

# %%
_ = 100

# %%
v100 = 1000

# %%
10  = 100
# Out:
#   File "<ipython-input-17-e256f0ef598f>", line 1
#     10  = 100
#     ^
# SyntaxError: cannot assign to literal

# %%
v 1 = 100
# Out:
#   File "<ipython-input-18-56f21a18d4a9>", line 1
#     v 1 = 100
#       ^
# SyntaxError: invalid syntax

# %%
    = 10
# Out:
#   File "<ipython-input-19-aaa014e91167>", line 1
#     = 10
#     ^
# SyntaxError: invalid syntax

# %%
# single variable assignment
v = 100

# %%
# multuple variable assignment
v1 = v2 = v3 = 100

# %%
v2
# Out:
# 100

# %%
v1,v2,v3 = 100
v1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-8081a8d56b9b> in <module>
# ----> 1 v1,v2,v3 = 100
#       2 v1
#
# TypeError: cannot unpack non-iterable int object

# %%
# multiple variable assignments
n1,n2,n3 = 10,100,1000
n3
# Out:
# 1000

# %%
n1 = 11,22,33,44
n1
# Out:
# (11, 22, 33, 44)

# %%
# indentation
# if (10>100){
#     printf("NO")
# }

if 10>100:
    print("NO")
else:
    print("Yes")
# Out:
#   File "<ipython-input-29-b04663644231>", line 7
#     print("NO")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ### Data type
# - char,float,int,double,bool,list,str,
#
# Text Type:	str
#
# Numeric Types:	int, float, complex
#
# Sequence Types:	list, tuple, range
#
# Mapping Type:	dict
#
# Set Types:	set, frozenset
#
# Boolean Type:	bool

# %%
s = 'apssdc'

# %%
type(s)
# Out:
# str

# %%
s = "apssdc"
type(s)
# Out:
# str

# %%
s = """apssdc"""
print(type(s))
# Out:
# <class 'str'>

# %%
s1 = 'i don\'t know'
s1
# Out:
# "i don't know"

# %%
s1 = "i don't know"
s1
# Out:
# "i don't know"

# %%
s2 = """hi hello 
hello guys
welcome to apssdc
DS internship"""
s2
# Out:
# 'hi hello \nhello guys\nwelcome to apssdc\nDS internship'

# %%
n = 100
print(type(n))
# Out:
# <class 'int'>

# %%
f = 100.89
print(type(f))
# Out:
# <class 'float'>

# %%
c = 9j
type(c)
# Out:
# complex

# %% [markdown]
# ### List
# - orderly collection of items
# - A group of elements with same data types
# - it can have different data types
# - collection of elements seperated by , and enclosed with []
# - mutable - changable - add/append,update,remove...
# - can manupulate the elements in it

# %%
li = [1,2,2,3,4]
type(li)
# Out:
# list

# %%
l2 = [12,23,34.456,98j,"string"]

# %%
type(l2)
# Out:
# list

# %% [markdown]
# ### Tuple
# - its enclosed with brackets
# - same as list but immutable
# - Tuple is a built-in data type
# - Tuple is also a collection of elements but it's immutable and enclosed with ( )
# - A tuple is a collection of objects which ordered and immutable
# - A tuple is another sequence data type that is similar to the list.
# - A list is used to store multiple items in one variable and can be created using square brackets. Similarly, tuples also can store multiple items in a single variable and can be declared using parentheses.
# - Immutable means we can't do anything on tuple

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = tuple()
type(t)
# Out:
# tuple

# %%
t = (12,34,45,56,7)
t.add(90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-ea1f9fbf2f62> in <module>
#       1 t = (12,34,45,56,7)
# ----> 2 t.add(90)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# ### Range
# - range(start_value,end_value,skip_value)
# - default start value from 0
# - default skip value from 1

# %% [raw]
# for i = 0,i<100,i++{
#
# }

# %%
r = range(1,100,10)

# %%
type(r)
# Out:
# range

# %%
for i in range(1,100,10):
    print(i)
# Out:
# 1
# 11
# 21
# 31
# 41
# 51
# 61
# 71
# 81
# 91

# %% [markdown]
# ### Dictionary
# - Map object
# - it's a key & value pair
# - which is represented by {}
# - each item seperated by , and key:value
# - Mutable data structure
# - Unordered collection of elements
# - key and value pair we called as item of that dict

# %%
di = {}
type(di)
# Out:
# dict

# %%
d1 = dict()
type(d1)
# Out:
# dict

# %%
d1 = {"kumar":504,
     "Meghana":121,
     "saketh":348}
d1
# Out:
# {'kumar': 504, 'Meghana': 121, 'saketh': 348}

# %% [markdown]
# ### Sets
# - set is collection of elements
# - Unordered collection of elements
# - Sets is a collection of elements.
# - A set doesn't allow the duplicated elements.
# - It's mutable.

# %%
s = {12,344,46,56,67}
type(s)
# Out:
# set

# %%
s = set()
type(s)
# Out:
# set

# %%
s = {12,23,43,12,23,23}
s.add(90)
s
# Out:
# {12, 23, 43, 90}

# %% [markdown]
# ### Frozen set
# - Immutable
# - same as set

# %%
fs = frozenset({12,23,34,45})
fs
# Out:
# frozenset({12, 23, 34, 45})

# %%
type(fs)
# Out:
# frozenset

# %% [markdown]
# ### Boolean
# - True
# - False

# %%
type(12 == 12)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Type Casting
# - Converting one data type to another
# - Changing the data types

# %%
str(90) # int to str
# Out:
# '90'

# %%
str(909.89) # float to str
# Out:
# '909.89'

# %%
str(89j) # comple to str
# Out:
# '89j'

# %%
str("str") # str to str
# Out:
# 'str'

# %%
int("A") # str to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-3811419b7f72> in <module>
# ----> 1 int("A") # str to int
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
int("100") # str to int
# Out:
# 100

# %%
int(234.456) # float to int
# Out:
# 234

# %%
int(9j+9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-b87bda7888c5> in <module>
# ----> 1 int(9j+9)
#
# TypeError: can't convert complex to int

# %%
float("100") # str to float
# Out:
# 100.0

# %%
float(1000) # int to float
# Out:
# 1000.0

# %%
float(123.345) # float to float
# Out:
# 123.345

# %%
float(9j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-137d739dd3d5> in <module>
# ----> 1 float(9j)
#
# TypeError: can't convert complex to float

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(90)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("str")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %% [markdown]
# ### ord, chr

# %%
ord("A")
# Out:
# 65

# %%
ord("Z")
# Out:
# 90

# %%
ord("a")
# Out:
# 97

# %%
ord("z")
# Out:
# 122

# %%
ord("0")
# Out:
# 48

# %%
ord("9")
# Out:
# 57

# %%
chr(100)
# Out:
# 'd'

# %%
chr(_)
# Out:
# 'd'

# %%
chr(120)
# Out:
# 'x'

# %%
chr(200)
# Out:
# 'È'

# %%
chr(10)
# Out:
# '\n'

# %%
chr(27)
# Out:
# '\x1b'

# %%
chr(12)
# Out:
# '\x0c'

# %%
chr(1)
# Out:
# '\x01'

# %%
chr(20)
# Out:
# '\x14'

# %% [markdown]
# #### Convert your name into ASCII

# %%
"a"+"a"
# Out:
# 'aa'

# %%
987654322345

# %%
"hi"
str(ord("H"))+str(ord("I"))
# Out:
# '7273'

# %% [markdown]
# Masoom:'10997115111111109'

# %%
ord("H")+ord("I")
# Out:
# 145

# %% [markdown]
# ### Dynamic Input Reading

# %%
s = input()
print("hi this is ",s)
# Out:
# lavanya
# hi this is  lavanya

# %%
s = input("enter your sweet name")
print("hi this is ",s)
# Out:
# enter your sweet nameLavanya
# hi this is  Lavanya

# %%
s = input("Enter your Package")
print("My Annual Package is ",s)
type(s)
# Out:
# Enter your Packagefive lakhs
# My Annual Package is  five lakhs
# str

# %%
# default input function returns only string

# %%
s = float(input("Enter your Package"))
print("My Annual Package is ",s)
type(s)
# Out:
# Enter your Packagefive lakhs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-9cf7b23f8646> in <module>
# ----> 1 s = float(input("Enter your Package"))
#       2 print("My Annual Package is ",s)
#       3 type(s)
#
# ValueError: could not convert string to float: 'five lakhs'

# %%
s = float(input("Enter your Package"))
print("My Annual Package is ",s)
type(s)
# Out:
# Enter your Package12
# My Annual Package is  12.0
# float

# %%
age = int(input("Enter your age"))
print("i am ",age)
# Out:
# Enter your age20
# i am  20

# %%
age_boy = int(input("Enter your age"))
age_girl = int(input("Enter your age"))
print("girl age is ",age_girl, "Boy age is ",age_boy)
# Out:
# Enter your age20
# Enter your age23
# girl age is  23 Boy age is  20

# %%
age_boy = int(input("Enter your age"))
age_girl = int(input("Enter your age"))
print("girl age is  {1} Boy age is {0}".format(age_boy,age_girl))
# Out:
# Enter your age23
# Enter your age20
# girl age is  1 Boy age is 0

# %%
s = float(input("Enter your Package"))
print("My Annual Package is {:.2f} ".format(s))
type(s)
# Out:
# Enter your Package12.3454656
# My Annual Package is 12.35
# float

# %%
round(12.2344,1)
# Out:
# 12.2

# %% [markdown]
# # Operators
#
# - To perform some operations
# - for numerical operations
# - comparsion
# - logical
# - assignment
# - bitwise
# - arthmetic
# - it gives relation between two or more operands

# %% [markdown]
#     A. Arithmetic Operators ( +,-,%,/,//,*)
#
#     B. Assignment Operators ( =, +=, -=, *=, %=, /=, //=)
#
#     C. Comparison operators ( ==, >=, <=, !=, >, < )
#
#     D. Logical operators ( and, or, not )
#
#     E. Bitwise Operators ( &, |, ~, ^, >>, <<)
#
#     F. Identity Operators ( is , is not )
#
#     G. Membership Operators ( in , not in )

# %% [markdown]
# ### A. Arithmetic Operators ( +,-,%,/,//,*)

# %%
a=5
b=10
print(a+b)
print(a-b)
print(a%b),a/b,a//b,a*b
# Out:
# 15
# -5
# 5
# (None, 0.5, 0, 50)

# %%
a=5
b=10
a+b,a-b,a%b,a/b,a//b,a*b
# Out:
# (15, -5, 5, 0.5, 0, 50)

# %%
a=10
b=23
print(a+b) # add
print(a-b) # sub
print(a*b) # mul
print(a/b) # div
print(a//b) # float div
print(a%b) # mod
# Out:
# 33
# -13
# 230
# 0.43478260869565216
# 0
# 10

# %%
a = 100
b = 0
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-164-e934e4455023> in <module>
#       1 a = 100
#       2 b = 0
# ----> 3 a/b
#
# ZeroDivisionError: division by zero

# %%
a = 12
b = 10
print(a+b) #Adds
print(a-b) #Subtracts
print(a*b) #Multiplies
print(a/b) #Returns quotient after division
print(a//b) #Returns int value of quotient after division. 
print(a%b) #Returns remainder after division
# Out:
# 22
# 2
# 120
# 1.2
# 1
# 2

# %% [markdown]
# ## B. Assignment Operators ( =, +=, -=, *=, %=, /=, //=)

# %%
v = 1
v = v+1
v
# Out:
# 2

# %%
v += 1

# %%
v
# Out:
# 3

# %%
a=9
print(a)
a+=1
print(a)
a*=1
print(a)
a/=3
print(a)
a%=1
print(a)
a//=1
print(a)
# Out:
# 9
# 10
# 10
# 3.3333333333333335
# 0.3333333333333335
# 0.0

# %% [markdown]
# ## C. Comparison operators ( ==, >=, <=, !=, >, < )
# - returns only bool output True or False

# %%
a == 100
# Out:
# False

# %%
a
# Out:
# 0.0

# %%
a=9
b=10
print(a==b)
print(a<=b)
print(a>=b)
print(a>b)
print(a<b)
print(a!=b)
# Out:
# False
# True
# False
# False
# True
# True

# %% [markdown]
# ## D. Logical operators ( and, or, not )
# - and gate - both conditions must be true returns True else False
# - or gate  - atleast one condition is true it returns true else False
# - not      - Opposite of input

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
12 and 34
# Out:
# 34

# %%
34 and 45  # if both inputs are true, and gate returns only right side value
# Out:
# 45

# %%
1234256 and 1
# Out:
# 1

# %%
12 and 3234564786
# Out:
# 3234564786

# %%
1 and 0
# Out:
# 0

# %%
0 and 1
# Out:
# 0

# %%
12 or 234
# Out:
# 12

# %%
2 or 46
# Out:
# 2

# %%
1 or 0
# Out:
# 1

# %%
0 or 1 # if any one value is true it returns True value only
# if both values are True, it returns left side value
# Out:
# 1

# %%
not False
# Out:
# True

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not -1
# Out:
# False

# %% [markdown]
# ## E. Bitwise Operators ( &, |, ~, ^, >>, <<)

# %%
2 & 10
# Out:
# 2

# %% [raw]
# 2 -- 0010
# 10 - 1010
# &  - 0010   -- 2

# %%
10 & 15
# Out:
# 10

# %%
10 -- 1010
15 -- 1111
&  -- 1010 - 10

# %%
2 | 5
# Out:
# 7

# %% [raw]
# 2 --- 0010
# 5 --- 0101
# | ----0111 -- 7

# %%
print(-(1+1))
~ 1
# Out:
# -2
# -2

# %%
print(-(0+1))
~ 0
# Out:
# -1
# -1

# %%
~ -1
# Out:
# 0

# %%
~ 3
# Out:
# -4

# %%
# -(n+1)

# %%
# >> right shift
10 >> 2 # div your value with 2 by given number of times
# Out:
# 2

# %%
10  -- 1010
1   -- 0100
2   -- 0010   - 2

# %%
10//2
# Out:
# 5

# %%
5//2
# Out:
# 2

# %%
15 >> 3
# Out:
# 1

# %%
15//2
# Out:
# 7

# %%
7//2
# Out:
# 3

# %%
3//2
# Out:
# 1

# %% [markdown]
# 15 -- 1111
# 1  -- 0111
# 2 --- 0011
# 3 --- 0001   - 1

# %%
# << left shift

# %%
3 << 2
# Out:
# 12

# %% [markdown]
# 3 -- 0011
# 1 -- 0110
# 2 -- 1100  - 12

# %%
3*2
# Out:
# 6

# %%
6*2
# Out:
# 12

# %%
3 ^ 10
# Out:
# 9

# %% [markdown]
# 3   --  0011
# 10  --  1010
# ^   --  1001   - 9

# %% [markdown]
# ## F. Identity Operators ( is , is not )
#
# ## G. Membership Operators ( in , not in )

# %%
12 is 12
# == comparision values
# is also for comparision,compares  value  & location
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-224-88dea4c2f5b2>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   12 is 12
# True

# %%
12 is not 12
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-225-694275cd5f17>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   12 is not 12
# False

# %%
166 in [348,236,246,246,245,45,89]
# Out:
# False

# %%
166 not in [348,236,246,246,245,45,89]
# Out:
# True

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(str.capitalize)
# Out:
# Help on method_descriptor:
#
# capitalize(self, /)
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
str.capitalize?

# %% [markdown]
# # Number Conversion
# - decimal
# - hexa
# - octal
# - Binary

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(90)
# Out:
# '0b1011010'

# %%
bin(0)
# Out:
# '0b0'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(15)
# Out:
# '0xf'

# %%
oct(12)
# Out:
# '0o14'

# %%
oct(7)
# Out:
# '0o7'

# %%
oct(8)
# Out:
# '0o10'

# %%
oct(10)
# Out:
# '0o12'

# %%
int(0o14)
# Out:
# 12

# %% [markdown]
# #  conditional Statements

# %%
if 10> 100:
    print("YEs")
