# %% [markdown]
# ![](logo.png)
#
# # Day Objectives
# ## Pandas
# - Pandas is a built in library using for data analysis. You'll be using Pandas heavily for data manipulation, visualisation, building machine learning models, etc.
# - Pandas implements a number of powerful data operations familiar to users of both database frameworks and spreadsheet programs.
# - There are two main data structures in Pandas - Series and Dataframes. The default way to store data is dataframes, and thus manipulating dataframes quickly is probably the most important skill set for data analysis.
# - Source: https://pandas.pydata.org/pandas-docs/stable/overview.html
# ## Pandas Series
# - A series is similar to a 1-D numpy array, and contains values of the same type (numeric, character, datetime  etc.). A dataframe is simply a table where each column is a pandas series.
#
# ## creating series
# - List
# - Tuple
# - Dictionary
# - Numpy
# - Date_Range
# - Series Indexing

# %% [markdown]
# ## Data Analysis with Pandas
#
#
# |S.No |Name |Gender|
# |--|--|--|
# |1 | Mercy | Female|
# |2 | Cherry | Male |
# |3 | Raju | Male |
#
#
# * Pandas DataFrame
# * Combining & Merging
# * File I/O
# * Indexing
# * sorting
# * Filtering

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lavan\anaconda3\lib\site-packages (1.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\lavan\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\lavan\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lavan\anaconda3\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\lavan\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %%
import pandas  as pd

# %%
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ## creating series

# %%
# convert list into pandas series
li = [213,345,456,6,776,4564,534345]
s1 = pd.Series(li)
s1
# each value in series having index 
# index starts from 0 to n
# Out:
# 0       213
# 1       345
# 2       456
# 3         6
# 4       776
# 5      4564
# 6    534345
# dtype: int64

# %%
# convertig tuple into series
t = (123,34,345.45,"APSSDC")
s2 = pd.Series(t)
s2
# Out:
# 0       123
# 1        34
# 2    345.45
# 3    APSSDC
# dtype: object

# %%
# converting Dict into Series
di = {"a":112,"b":345,"c":68}
s3 = pd.Series(di)
s3
# keys acts like index
# Out:
# a    112
# b    345
# c     68
# dtype: int64

# %%
# changing index values
l = [3234,456,34.8]
s4 = pd.Series(l,index = ["x",456,45.4])
s4
# index values can be any type of data
# Out:
# x       3234.0
# 456      456.0
# 45.4      34.8
# dtype: float64

# %%
# converting numpy into series
import numpy as np
n = np.array(l)
s5 = pd.Series(n)
s5
# Out:
# 0    3234.0
# 1     456.0
# 2      34.8
# dtype: float64

# %%
# Date_Range

s6 = pd.date_range(start = "2021-06-01",end = "2021-07-15")
s6
# Out:
# DatetimeIndex(['2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04',
#                '2021-06-05', '2021-06-06', '2021-06-07', '2021-06-08',
#                '2021-06-09', '2021-06-10', '2021-06-11', '2021-06-12',
#                '2021-06-13', '2021-06-14', '2021-06-15', '2021-06-16',
#                '2021-06-17', '2021-06-18', '2021-06-19', '2021-06-20',
#                '2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24',
#                '2021-06-25', '2021-06-26', '2021-06-27', '2021-06-28',
#                '2021-06-29', '2021-06-30', '2021-07-01', '2021-07-02',
#                '2021-07-03', '2021-07-04', '2021-07-05', '2021-07-06',
#                '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-10',
#                '2021-07-11', '2021-07-12', '2021-07-13', '2021-07-14',
#                '2021-07-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
help(pd.date_range)
# Out:
# Help on function date_range in module pandas.core.indexes.datetimes:
#
# date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize=False, name=None, closed=None, **kwargs) -> pandas.core.indexes.datetimes.DatetimeIndex
#     Return a fixed frequency DatetimeIndex.
#
#     Parameters
#     ----------
#     start : str or datetime-like, optional
#         Left bound for generating dates.
#     end : str or datetime-like, optional
#         Right bound for generating dates.
#     periods : int, optional
#         Number of periods to generate.
#     freq : str or DateOffset, default 'D'
#         Frequency strings can have multiples, e.g. '5H'. See
#         :ref:`here <timeseries.offset_aliases>` for a list of
#         frequency aliases.
#     tz : str or tzinfo, optional
#         Time zone name for returning localized DatetimeIndex, for example
#         'Asia/Hong_Kong'. By default, the resulting DatetimeIndex is
#         timezone-naive.
#     normalize : bool, default False
#         Normalize start/end dates to midnight before generating date range.
#     name : str, default None
#         Name of the resulting DatetimeIndex.
#     closed : {None, 'left', 'right'}, optional
#         Make the interval closed with respect to the given frequency to
#         the 'left', 'right', or both sides (None, the default).
#     **kwargs
#         For compatibility. Has no effect on the result.
#
#     Returns
#     -------
#     rng : DatetimeIndex
#
#     See Also
#     --------
#     DatetimeIndex : An immutable container for datetimes.
#     timedelta_range : Return a fixed frequency TimedeltaIndex.
#     period_range : Return a fixed frequency PeriodIndex.
#     interval_range : Return a fixed frequency IntervalIndex.
#
#     Notes
#     -----
#     Of the four parameters ``start``, ``end``, ``periods``, and ``freq``,
#     exactly three must be specified. If ``freq`` is omitted, the resulting
#     ``DatetimeIndex`` will have ``periods`` linearly spaced elements between
#     ``start`` and ``end`` (closed on both sides).
#
#     To learn more about the frequency strings, please see `this link
#     <https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases>`__.
#
#     Examples
#     --------
#     **Specifying the values**
#
#     The next four examples generate the same `DatetimeIndex`, but vary
#     the combination of `start`, `end` and `periods`.
#
#     Specify `start` and `end`, with the default daily frequency.
#
#     >>> pd.date_range(start='1/1/2018', end='1/08/2018')
#     DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                    '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08'],
#                   dtype='datetime64[ns]', freq='D')
#
#     Specify `start` and `periods`, the number of periods (days).
#
#     >>> pd.date_range(start='1/1/2018', periods=8)
#     DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                    '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08'],
#                   dtype='datetime64[ns]', freq='D')
#
#     Specify `end` and `periods`, the number of periods (days).
#
#     >>> pd.date_range(end='1/1/2018', periods=8)
#     DatetimeIndex(['2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#                    '2017-12-29', '2017-12-30', '2017-12-31', '2018-01-01'],
#                   dtype='datetime64[ns]', freq='D')
#
#     Specify `start`, `end`, and `periods`; the frequency is generated
#     automatically (linearly spaced).
#
#     >>> pd.date_range(start='2018-04-24', end='2018-04-27', periods=3)
#     DatetimeIndex(['2018-04-24 00:00:00', '2018-04-25 12:00:00',
#                    '2018-04-27 00:00:00'],
#                   dtype='datetime64[ns]', freq=None)
#
#     **Other Parameters**
#
#     Changed the `freq` (frequency) to ``'M'`` (month end frequency).
#
#     >>> pd.date_range(start='1/1/2018', periods=5, freq='M')
#     DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                    '2018-05-31'],
#                   dtype='datetime64[ns]', freq='M')
#
#     Multiples are allowed
#
#     >>> pd.date_range(start='1/1/2018', periods=5, freq='3M')
#     DatetimeIndex(['2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31',
#                    '2019-01-31'],
#                   dtype='datetime64[ns]', freq='3M')
#
#     `freq` can also be specified as an Offset object.
#
#     >>> pd.date_range(start='1/1/2018', periods=5, freq=pd.offsets.MonthEnd(3))
#     DatetimeIndex(['2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31',
#                    '2019-01-31'],
#                   dtype='datetime64[ns]', freq='3M')
#
#     Specify `tz` to set the timezone.
#
#     >>> pd.date_range(start='1/1/2018', periods=5, tz='Asia/Tokyo')
#     DatetimeIndex(['2018-01-01 00:00:00+09:00', '2018-01-02 00:00:00+09:00',
#                    '2018-01-03 00:00:00+09:00', '2018-01-04 00:00:00+09:00',
#                    '2018-01-05 00:00:00+09:00'],
#                   dtype='datetime64[ns, Asia/Tokyo]', freq='D')
#
#     `closed` controls whether to include `start` and `end` that are on the
#     boundary. The default includes boundary points on either end.
#
#     >>> pd.date_range(start='2017-01-01', end='2017-01-04', closed=None)
#     DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04'],
#                   dtype='datetime64[ns]', freq='D')
#
#     Use ``closed='left'`` to exclude `end` if it falls on the boundary.
#
#     >>> pd.date_range(start='2017-01-01', end='2017-01-04', closed='left')
#     DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03'],
#                   dtype='datetime64[ns]', freq='D')
#
#     Use ``closed='right'`` to exclude `start` if it falls on the boundary.
#
#     >>> pd.date_range(start='2017-01-01', end='2017-01-04', closed='right')
#     DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04'],
#                   dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Pandas Series Indexing

# %%
s1[0]
# Out:
# 213

# %%
s1[::-1] # reverse of the series
# Out:
# 6    534345
# 5      4564
# 4       776
# 3         6
# 2       456
# 1       345
# 0       213
# dtype: int64

# %%
s1[::2]
# Out:
# 0       213
# 2       456
# 4       776
# 6    534345
# dtype: int64

# %%
s2[1::2]
# Out:
# 1        34
# 3    APSSDC
# dtype: object

# %%
s1
# Out:
# 0       213
# 1       345
# 2       456
# 3         6
# 4       776
# 5      4564
# 6    534345
# dtype: int64

# %%
s1[3:]
# Out:
# 3         6
# 4       776
# 5      4564
# 6    534345
# dtype: int64

# %%
# access 3,6,2,4
# Fancy Indexing
s1[[3,6,2,4]]
# accessing Specified data
# Out:
# 3         6
# 6    534345
# 2       456
# 4       776
# dtype: int64

# %%
s3
# Out:
# a    112
# b    345
# c     68
# dtype: int64

# %%
s3["a"] # explicit slicing
# Out:
# 112

# %%
s3["c"]
# Out:
# 68

# %%
s3[0]  # implicit slicing
# Out:
# 112

# %%
# converting Dict into Series
di = {"a":112,"b":345,"d":np.nan,"c":68}
s7 = pd.Series(di)
s7
# NaN - not a number - a special type of float value
# Out:
# a    112.0
# b    345.0
# d      NaN
# c     68.0
# dtype: float64

# %%
s8 = pd.Series(di,index = ["a","d","c"])
s8
# Out:
# a    112.0
# d      NaN
# c     68.0
# dtype: float64

# %%
s9 = pd.Series("SRM",index = [290,392,435,234,324])
s9
# Out:
# 290    SRM
# 392    SRM
# 435    SRM
# 234    SRM
# 324    SRM
# dtype: object

# %% [markdown]
# # Task
# - Generate n - Table  using pandas series
#
# 1 -- 5
#
# 2 -- 10
#
# 3 -- 15

# %%
n = int(input())
ls = [i for i in range(n, (n*10)+1, n)]
s = pd.Series(ls, index=[i for i in range(1, 11)])
print(s)
# Out:
# 5
# 1      5
# 2     10
# 3     15
# 4     20
# 5     25
# 6     30
# 7     35
# 8     40
# 9     45
# 10    50
# dtype: int64

# %%
di = {1:5,2:10,3:15}
s7 = pd.Series(di)
s7
# here boundaaries fixed and table number also fixed
# Out:
# 1     5
# 2    10
# 3    15
# dtype: int64

# %%
list1=[x*5 for x in range(1,11)]
s1=pd.Series(list1,index=np.arange(1,11))
s1
# Out:
# 1      5
# 2     10
# 3     15
# 4     20
# 5     25
# 6     30
# 7     35
# 8     40
# 9     45
# 10    50
# dtype: int64

# %%
li = [5, 10, 15]
s = pd.Series(li, index=(1,2,3))
s
# Out:
# 1     5
# 2    10
# 3    15
# dtype: int64

# %%
pd.Series(np.arange(1,11)*5,index = np.arange(1,11))
# Out:
# 1      5
# 2     10
# 3     15
# 4     20
# 5     25
# 6     30
# 7     35
# 8     40
# 9     45
# 10    50
# dtype: int32

# %%
s5 ={1:5,2:10,3:15}
b7 = pd.Series(s5)
b7
# Out:
# 1     5
# 2    10
# 3    15
# dtype: int64

# %% [markdown]
# # Pandas DataFrame

# %%
# converting dict into Dataframe
di
# Out:
# {1: 5, 2: 10, 3: 15}

# %%
df1 = pd.DataFrame(di, index = ["a","b","c"])
df1
# keys acts like column names
# Out:
#    1   2   3
# a  5  10  15
# b  5  10  15
# c  5  10  15

# %%
df1.columns = ["X","Y","Z"]
df1
# Out:
#    X   Y   Z
# a  5  10  15
# b  5  10  15
# c  5  10  15

# %%
df1.shape # (rows,columns)
# Out:
# (3, 3)

# %%
# converting list into Df
df2 = pd.DataFrame([[1,2,3],[3,4,5],[6,7,8]])
df2
# columns and rows starts from 0
# Out:
#    0  1  2
# 0  1  2  3
# 1  3  4  5
# 2  6  7  8

# %%
df2.columns = ["er","56","df"]
df2
# Out:
#    er  56  df
# 0   1   2   3
# 1   3   4   5
# 2   6   7   8

# %%
df2.index = ["e","t","w"]
df2
# Out:
#    er  56  df
# e   1   2   3
# t   3   4   5
# w   6   7   8

# %%
d2 = {
    "Name":["HemaSundar","Manish","Vamsi"],
    "Gender":["Male","Male",np.nan],
    "PIN" : [481,512,345]
}
df3 = pd.DataFrame(d2)
df3
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481
# 1      Manish   Male  512
# 2       Vamsi    NaN  345

# %%
type(df3["Name"])
# Out:
# pandas.core.series.Series

# %%
df3["Name"]
# Out:
# 0    HemaSundar
# 1        Manish
# 2         Vamsi
# Name: Name, dtype: object

# %%
df3["PIN"]
# Out:
# 0    481
# 1    512
# 2    345
# Name: PIN, dtype: int64

# %%
df3["Name","PIN"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'PIN')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-6312a078bddc> in <module>
# ----> 1 df3["Name","PIN"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'PIN')

# %%
df3[["Name","PIN"]] # accessing sub df
# Out:
#          Name  PIN
# 0  HemaSundar  481
# 1      Manish  512
# 2       Vamsi  345

# %%
df3[2:3]
# Out:
#     Name Gender  PIN
# 2  Vamsi    NaN  345

# %%
df3[::-1]
# Out:
#          Name Gender  PIN
# 2       Vamsi    NaN  345
# 1      Manish   Male  512
# 0  HemaSundar   Male  481

# %%
df3["Name"]
# Out:
# 0    HemaSundar
# 1        Manish
# 2         Vamsi
# Name: Name, dtype: object

# %%
df3[:1]
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481

# %%
df3.set_index("Name")
# Out:
#            Gender  PIN
# Name
# HemaSundar   Male  481
# Manish       Male  512
# Vamsi         NaN  345

# %%
df3
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481
# 1      Manish   Male  512
# 2       Vamsi    NaN  345

# %%
df3.set_index("Name", inplace = True) # changing original df

# %%
df3
# Out:
#            Gender  PIN
# Name
# HemaSundar   Male  481
# Manish       Male  512
# Vamsi         NaN  345

# %% [markdown]
# ## iloc -- for accessing rows using integer indicies
# ## loc -- for accessing rows other than integer indicies

# %%
df3.iloc[0]
# Out:
# Gender    Male
# PIN        481
# Name: HemaSundar, dtype: object

# %%
df3[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-62a59a1bf4da> in <module>
# ----> 1 df3[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
df3.iloc[2]
# Out:
# Gender    NaN
# PIN       345
# Name: Vamsi, dtype: object

# %%
df3.loc["HemaSundar"]
# Out:
# Gender    Male
# PIN        481
# Name: HemaSundar, dtype: object

# %%
df3.loc[["Manish","Vamsi"]]
# Out:
#        Gender  PIN
# Name
# Manish   Male  512
# Vamsi     NaN  345

# %%
df3.loc[["Manish","Vamsi"], "PIN"]
# Out:
# Name
# Manish    512
# Vamsi     345
# Name: PIN, dtype: int64

# %%
df3.reset_index(inplace = True)

# %%
df3
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481
# 1      Manish   Male  512
# 2       Vamsi    NaN  345

# %% [markdown]
# # File Reading

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/AP-Skill-Development-Corporation/DataScienceUsingPython-Internship-SRM-University/main/Day12_Pandas/iris.csv")
df4
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0             0                5.1               3.5                1.4
# 1             1                4.9               3.0                1.4
# 2             2                4.7               3.2                1.3
# 3             3                4.6               3.1                1.5
# 4             4                5.0               3.6                1.4
# ..          ...                ...               ...                ...
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  Target
# 0                 0.2       0
# 1                 0.2       0
# 2                 0.2       0
# 3                 0.2       0
# 4                 0.2       0
# ..                ...     ...
# 145               2.3       2
# 146               1.9       2
# 147               2.0       2
# 148               2.3       2
# 149               1.8       2
#
# [150 rows x 6 columns]

# %%
df4 = pd.read_csv("iris.csv")
df4
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0             0                5.1               3.5                1.4
# 1             1                4.9               3.0                1.4
# 2             2                4.7               3.2                1.3
# 3             3                4.6               3.1                1.5
# 4             4                5.0               3.6                1.4
# ..          ...                ...               ...                ...
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  Target
# 0                 0.2       0
# 1                 0.2       0
# 2                 0.2       0
# 3                 0.2       0
# 4                 0.2       0
# ..                ...     ...
# 145               2.3       2
# 146               1.9       2
# 147               2.0       2
# 148               2.3       2
# 149               1.8       2
#
# [150 rows x 6 columns]

# %%
df5 = pd.read_excel("2020-07-25.xlsx")

# %%
df5
# Out:
#     Unnamed: 0 Roll Number 2020-07-25
# 0            0  17B81A04H1          P
# 1            1  198A5F0019          P
# 2            2  17KD1A0560          P
# 3            3  17KH1A0455          P
# 4            4  1210316262          P
# 5            5  18P31A0555          P
# 6            6  18B01A0211          P
# 7            7    Y18IT048          P
# 8            8  17B81A05B2          P
# 9            9  169X1A04E0          P
# 10          10  14F41A0447          P
# 11          11  17W51D5505          P
# 12          12  18021D0501          P
# 13          13    Y18CS034          P
# 14          14    Y18IT040          P
# 15          15  154M1A0554          P
# 16          16  19025A0433          P
# 17          17   180030816          P
# 18          18  18A31A1248          P
# 19          19    Y18IT020          P
# 20          20  18AT1A0527          P
# 21          21  18121A02D0          P
# 22          22    Y18IT055          P
# 23          23  17NE1A0578          P
# 24          24    Y17CS108          P
# 25          25    Y18IT063          P
# 26          26    Y18IT043          P
# 27          27  178B1A0561          P
# 28          28  19A95F0019          P
# 29          29   180050012          P
# 30          30  166N1A0546          P
# 31          31   170040246          P
# 32          32  188W1A0460          P
# 33          33  14B21A04E1          P
# 34          34  18AT1A0559          P
# 35          35     N160868          P
# 36          36  153B1A0538          P
# 37          37  17751A0408          P
# 38          38  18G31A0439          P
# 39          39   180030523          P
# 40          40    Y18IT029          P
# 41          41  18A81A05M5          P
# 42          42  18A51A1206          P
# 43          43  18B91A0209          P
# 44          44  1210416462          P
# 45          45     R151263          P
# 46          46     Y18CS80          P
# 47          47  17F21A0348          P
# 48          48  10G11A0209          P
# 49          49  19B95A0512          P
# 50          50    Y18IT025          P
# 51          51    Y18IT092          P
# 52          52    Y18CS166          P
# 53          53     R141465          P
# 54          54  17JN1A0495          P
# 55          55   170031480          P
# 56          56  2020239167          P

# %%
df4.head()
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           0                5.1               3.5                1.4
# 1           1                4.9               3.0                1.4
# 2           2                4.7               3.2                1.3
# 3           3                4.6               3.1                1.5
# 4           4                5.0               3.6                1.4
#
#    petal width (cm)  Target
# 0               0.2       0
# 1               0.2       0
# 2               0.2       0
# 3               0.2       0
# 4               0.2       0

# %%
df4.head(2)
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           0                5.1               3.5                1.4
# 1           1                4.9               3.0                1.4
#
#    petal width (cm)  Target
# 0               0.2       0
# 1               0.2       0

# %%
df4.tail()
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  Target
# 145               2.3       2
# 146               1.9       2
# 147               2.0       2
# 148               2.3       2
# 149               1.8       2

# %%
df4.tail(4)
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  Target
# 146               1.9       2
# 147               2.0       2
# 148               2.3       2
# 149               1.8       2

# %%
df4.sample()
# Out:
#     Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 44          44                5.1               3.8                1.9
#
#     petal width (cm)  Target
# 44               0.4       0

# %%
df4.iloc[3]
# Out:
# Unnamed: 0           3.0
# sepal length (cm)    4.6
# sepal width (cm)     3.1
# petal length (cm)    1.5
# petal width (cm)     0.2
# Target               0.0
# Name: 3, dtype: float64

# %%
df4.iloc[100]
# Out:
# Unnamed: 0           100.0
# sepal length (cm)      6.3
# sepal width (cm)       3.3
# petal length (cm)      6.0
# petal width (cm)       2.5
# Target                 2.0
# Name: 100, dtype: float64

# %%
len(df4.columns)
# Out:
# 6

# %%
df4.shape[0]
# Out:
# 150

# %%
df4.shape
# Out:
# (150, 6)

# %%
df4["sepal length (cm)"] # accessing column as pandas series
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
df4[["sepal length (cm)","petal width (cm)"]] # 2 columns as sub df
# Out:
#      sepal length (cm)  petal width (cm)
# 0                  5.1               0.2
# 1                  4.9               0.2
# 2                  4.7               0.2
# 3                  4.6               0.2
# 4                  5.0               0.2
# ..                 ...               ...
# 145                6.7               2.3
# 146                6.3               1.9
# 147                6.5               2.0
# 148                6.2               2.3
# 149                5.9               1.8
#
# [150 rows x 2 columns]

# %%
df4.describe()
# Out:
#        Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count  150.000000         150.000000        150.000000         150.000000
# mean    74.500000           5.843333          3.057333           3.758000
# std     43.445368           0.828066          0.435866           1.765298
# min      0.000000           4.300000          2.000000           1.000000
# 25%     37.250000           5.100000          2.800000           1.600000
# 50%     74.500000           5.800000          3.000000           4.350000
# 75%    111.750000           6.400000          3.300000           5.100000
# max    149.000000           7.900000          4.400000           6.900000
#
#        petal width (cm)      Target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df4.sum()
# Out:
# Unnamed: 0           11175.0
# sepal length (cm)      876.5
# sepal width (cm)       458.6
# petal length (cm)      563.7
# petal width (cm)       179.9
# Target                 150.0
# dtype: float64

# %%
df4.count()
# Out:
# Unnamed: 0           150
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# Target               150
# dtype: int64

# %%
df4.max()
# Out:
# Unnamed: 0           149.0
# sepal length (cm)      7.9
# sepal width (cm)       4.4
# petal length (cm)      6.9
# petal width (cm)       2.5
# Target                 2.0
# dtype: float64

# %%
df4.std()
# Out:
# Unnamed: 0           43.445368
# sepal length (cm)     0.828066
# sepal width (cm)      0.435866
# petal length (cm)     1.765298
# petal width (cm)      0.762238
# Target                0.819232
# dtype: float64

# %% [markdown]
# # Sorting

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AP-Skill-Development-Corporation/DataScienceUsingPython-Internship-SRM-University/main/Day12_Pandas/Students%20(8).csv")
data
# Out:
#      S.No. Registration Id                         Name  \
# 0        1   AP19110010001  Tata Lakshmi Durga Likhitha
# 1        2   AP19110010003            Bhuvana Venigalla
# 2        3   AP19110010005    Kanagala Yoga Sai Abhigna
# 3        4   AP19110010006  Likhitha Parvathi Tadikonda
# 4        5   AP19110010007   Jaya Ganesh Kumar Gudipati
# ..     ...             ...                          ...
# 140    141   AP19110020052                       Mahesh
# 141    142   AP19110020077                Saptharishi.D
# 142    143   AP19110020077          Saptharishi Reddy.D
# 143    144   AP19110020106    Karnatapu Sri Sai Dhanush
# 144    145    AP1911010183       Tiwari Dharmesh Sharma
#
#                                 Email   Mobile No
# 0            tatalikhitha01@gmail.com  7287982736
# 1          venigallabhuvana@gmail.com  7989023905
# 2         abhignakanagala21@gmail.com  9390089242
# 3        t.likhithaparvathi@gmail.com  8099140764
# 4          jayaganeshkumarg@gmail.com  7330654249
# ..                                ...         ...
# 140          mahesh2001.sis@gmail.com  7989651824
# 141              0123saptha@gmail.com  9000666305
# 142              0123saptha@gmail.com  9000666305
# 143    dhanushkarnatapu1440@gmail.com  9398018626
# 144  dharmeshsharma17122002@gmail.com  9704043879
#
# [145 rows x 5 columns]

# %%
data.sort_index(axis = 0, ascending=True) # axis = 1 columns sort
# axis = 0 index sorting
# Out:
#      S.No. Registration Id                         Name  \
# 0        1   AP19110010001  Tata Lakshmi Durga Likhitha
# 1        2   AP19110010003            Bhuvana Venigalla
# 2        3   AP19110010005    Kanagala Yoga Sai Abhigna
# 3        4   AP19110010006  Likhitha Parvathi Tadikonda
# 4        5   AP19110010007   Jaya Ganesh Kumar Gudipati
# ..     ...             ...                          ...
# 140    141   AP19110020052                       Mahesh
# 141    142   AP19110020077                Saptharishi.D
# 142    143   AP19110020077          Saptharishi Reddy.D
# 143    144   AP19110020106    Karnatapu Sri Sai Dhanush
# 144    145    AP1911010183       Tiwari Dharmesh Sharma
#
#                                 Email   Mobile No
# 0            tatalikhitha01@gmail.com  7287982736
# 1          venigallabhuvana@gmail.com  7989023905
# 2         abhignakanagala21@gmail.com  9390089242
# 3        t.likhithaparvathi@gmail.com  8099140764
# 4          jayaganeshkumarg@gmail.com  7330654249
# ..                                ...         ...
# 140          mahesh2001.sis@gmail.com  7989651824
# 141              0123saptha@gmail.com  9000666305
# 142              0123saptha@gmail.com  9000666305
# 143    dhanushkarnatapu1440@gmail.com  9398018626
# 144  dharmeshsharma17122002@gmail.com  9704043879
#
# [145 rows x 5 columns]

# %%
data.sort_index(axis = 0, ascending=False)
# Out:
#      S.No. Registration Id                         Name  \
# 144    145    AP1911010183       Tiwari Dharmesh Sharma
# 143    144   AP19110020106    Karnatapu Sri Sai Dhanush
# 142    143   AP19110020077          Saptharishi Reddy.D
# 141    142   AP19110020077                Saptharishi.D
# 140    141   AP19110020052                       Mahesh
# ..     ...             ...                          ...
# 4        5   AP19110010007   Jaya Ganesh Kumar Gudipati
# 3        4   AP19110010006  Likhitha Parvathi Tadikonda
# 2        3   AP19110010005    Kanagala Yoga Sai Abhigna
# 1        2   AP19110010003            Bhuvana Venigalla
# 0        1   AP19110010001  Tata Lakshmi Durga Likhitha
#
#                                 Email   Mobile No
# 144  dharmeshsharma17122002@gmail.com  9704043879
# 143    dhanushkarnatapu1440@gmail.com  9398018626
# 142              0123saptha@gmail.com  9000666305
# 141              0123saptha@gmail.com  9000666305
# 140          mahesh2001.sis@gmail.com  7989651824
# ..                                ...         ...
# 4          jayaganeshkumarg@gmail.com  7330654249
# 3        t.likhithaparvathi@gmail.com  8099140764
# 2         abhignakanagala21@gmail.com  9390089242
# 1          venigallabhuvana@gmail.com  7989023905
# 0            tatalikhitha01@gmail.com  7287982736
#
# [145 rows x 5 columns]

# %%
data.sort_index(axis = 1, ascending=False)
# Out:
#      S.No. Registration Id                         Name   Mobile No  \
# 0        1   AP19110010001  Tata Lakshmi Durga Likhitha  7287982736
# 1        2   AP19110010003            Bhuvana Venigalla  7989023905
# 2        3   AP19110010005    Kanagala Yoga Sai Abhigna  9390089242
# 3        4   AP19110010006  Likhitha Parvathi Tadikonda  8099140764
# 4        5   AP19110010007   Jaya Ganesh Kumar Gudipati  7330654249
# ..     ...             ...                          ...         ...
# 140    141   AP19110020052                       Mahesh  7989651824
# 141    142   AP19110020077                Saptharishi.D  9000666305
# 142    143   AP19110020077          Saptharishi Reddy.D  9000666305
# 143    144   AP19110020106    Karnatapu Sri Sai Dhanush  9398018626
# 144    145    AP1911010183       Tiwari Dharmesh Sharma  9704043879
#
#                                 Email
# 0            tatalikhitha01@gmail.com
# 1          venigallabhuvana@gmail.com
# 2         abhignakanagala21@gmail.com
# 3        t.likhithaparvathi@gmail.com
# 4          jayaganeshkumarg@gmail.com
# ..                                ...
# 140          mahesh2001.sis@gmail.com
# 141              0123saptha@gmail.com
# 142              0123saptha@gmail.com
# 143    dhanushkarnatapu1440@gmail.com
# 144  dharmeshsharma17122002@gmail.com
#
# [145 rows x 5 columns]

# %%
data.sort_index(axis = 1, ascending=True)
# Out:
#                                 Email   Mobile No  \
# 0            tatalikhitha01@gmail.com  7287982736
# 1          venigallabhuvana@gmail.com  7989023905
# 2         abhignakanagala21@gmail.com  9390089242
# 3        t.likhithaparvathi@gmail.com  8099140764
# 4          jayaganeshkumarg@gmail.com  7330654249
# ..                                ...         ...
# 140          mahesh2001.sis@gmail.com  7989651824
# 141              0123saptha@gmail.com  9000666305
# 142              0123saptha@gmail.com  9000666305
# 143    dhanushkarnatapu1440@gmail.com  9398018626
# 144  dharmeshsharma17122002@gmail.com  9704043879
#
#                             Name Registration Id  S.No.
# 0    Tata Lakshmi Durga Likhitha   AP19110010001      1
# 1              Bhuvana Venigalla   AP19110010003      2
# 2      Kanagala Yoga Sai Abhigna   AP19110010005      3
# 3    Likhitha Parvathi Tadikonda   AP19110010006      4
# 4     Jaya Ganesh Kumar Gudipati   AP19110010007      5
# ..                           ...             ...    ...
# 140                       Mahesh   AP19110020052    141
# 141                Saptharishi.D   AP19110020077    142
# 142          Saptharishi Reddy.D   AP19110020077    143
# 143    Karnatapu Sri Sai Dhanush   AP19110020106    144
# 144       Tiwari Dharmesh Sharma    AP1911010183    145
#
# [145 rows x 5 columns]

# %%
data.sort_values("Name", ascending=True)
# Out:
#      S.No. Registration Id                                    Name  \
# 25      26   AP19110010090                          Abhinav Challa
# 7        8   AP19110010013                      Addepalli Srilekha
# 65      66   AP19110010230                     Akkineni Sohith Sai
# 66      67   AP19110010230                     Akkineni Sohith Sai
# 40      41   AP19110010131                         Anishita Kakani
# ..     ...             ...                                     ...
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 91      92   AP19110010320                            Yogitha Goli
#
#                               Email   Mobile No
# 25          abhinavch3011@gmail.com  9182522042
# 7             serevalli12@gmail.com  8688225663
# 65   saiakkinenisohith312@gmail.com  7032338671
# 66   saiakkinenisohith312@gmail.com  7032338671
# 40              anishitak@gmail.com  9399939996
# ..                              ...         ...
# 35          akhilbabu3838@gmail.com  9121536598
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 105     umasankaryelchuri@gmail.com  9666961872
# 91        yogithagoli1702@gmail.com  9701802216
#
# [145 rows x 5 columns]

# %%
data.sort_values("Name",ascending=False)
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# ..     ...             ...                                     ...
# 40      41   AP19110010131                         Anishita Kakani
# 66      67   AP19110010230                     Akkineni Sohith Sai
# 65      66   AP19110010230                     Akkineni Sohith Sai
# 7        8   AP19110010013                      Addepalli Srilekha
# 25      26   AP19110010090                          Abhinav Challa
#
#                               Email   Mobile No
# 91        yogithagoli1702@gmail.com  9701802216
# 105     umasankaryelchuri@gmail.com  9666961872
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 35          akhilbabu3838@gmail.com  9121536598
# ..                              ...         ...
# 40              anishitak@gmail.com  9399939996
# 66   saiakkinenisohith312@gmail.com  7032338671
# 65   saiakkinenisohith312@gmail.com  7032338671
# 7             serevalli12@gmail.com  8688225663
# 25          abhinavch3011@gmail.com  9182522042
#
# [145 rows x 5 columns]

# %%
data.sort_values(["Name","Registration Id"], ascending=False)
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# ..     ...             ...                                     ...
# 40      41   AP19110010131                         Anishita Kakani
# 65      66   AP19110010230                     Akkineni Sohith Sai
# 66      67   AP19110010230                     Akkineni Sohith Sai
# 7        8   AP19110010013                      Addepalli Srilekha
# 25      26   AP19110010090                          Abhinav Challa
#
#                               Email   Mobile No
# 91        yogithagoli1702@gmail.com  9701802216
# 105     umasankaryelchuri@gmail.com  9666961872
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 35          akhilbabu3838@gmail.com  9121536598
# ..                              ...         ...
# 40              anishitak@gmail.com  9399939996
# 65   saiakkinenisohith312@gmail.com  7032338671
# 66   saiakkinenisohith312@gmail.com  7032338671
# 7             serevalli12@gmail.com  8688225663
# 25          abhinavch3011@gmail.com  9182522042
#
# [145 rows x 5 columns]

# %%
data
# Out:
#      S.No. Registration Id                         Name  \
# 0        1   AP19110010001  Tata Lakshmi Durga Likhitha
# 1        2   AP19110010003            Bhuvana Venigalla
# 2        3   AP19110010005    Kanagala Yoga Sai Abhigna
# 3        4   AP19110010006  Likhitha Parvathi Tadikonda
# 4        5   AP19110010007   Jaya Ganesh Kumar Gudipati
# ..     ...             ...                          ...
# 140    141   AP19110020052                       Mahesh
# 141    142   AP19110020077                Saptharishi.D
# 142    143   AP19110020077          Saptharishi Reddy.D
# 143    144   AP19110020106    Karnatapu Sri Sai Dhanush
# 144    145    AP1911010183       Tiwari Dharmesh Sharma
#
#                                 Email   Mobile No
# 0            tatalikhitha01@gmail.com  7287982736
# 1          venigallabhuvana@gmail.com  7989023905
# 2         abhignakanagala21@gmail.com  9390089242
# 3        t.likhithaparvathi@gmail.com  8099140764
# 4          jayaganeshkumarg@gmail.com  7330654249
# ..                                ...         ...
# 140          mahesh2001.sis@gmail.com  7989651824
# 141              0123saptha@gmail.com  9000666305
# 142              0123saptha@gmail.com  9000666305
# 143    dhanushkarnatapu1440@gmail.com  9398018626
# 144  dharmeshsharma17122002@gmail.com  9704043879
#
# [145 rows x 5 columns]

# %%
data.sort_values(["Name","Registration Id"], ascending=False, inplace = True)
data
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# ..     ...             ...                                     ...
# 40      41   AP19110010131                         Anishita Kakani
# 65      66   AP19110010230                     Akkineni Sohith Sai
# 66      67   AP19110010230                     Akkineni Sohith Sai
# 7        8   AP19110010013                      Addepalli Srilekha
# 25      26   AP19110010090                          Abhinav Challa
#
#                               Email   Mobile No
# 91        yogithagoli1702@gmail.com  9701802216
# 105     umasankaryelchuri@gmail.com  9666961872
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 35          akhilbabu3838@gmail.com  9121536598
# ..                              ...         ...
# 40              anishitak@gmail.com  9399939996
# 65   saiakkinenisohith312@gmail.com  7032338671
# 66   saiakkinenisohith312@gmail.com  7032338671
# 7             serevalli12@gmail.com  8688225663
# 25          abhinavch3011@gmail.com  9182522042
#
# [145 rows x 5 columns]

# %% [markdown]
# # Combining or merging

# %%
d2 = {
    'Name': ['HemaSundar', 'Manish', 'Vamsi'],
     'Gender': ['Male', 'Male', np.nan],
     'PIN': [481, 512, 345]
     }
df1 = pd.DataFrame(d2)
df1
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481
# 1      Manish   Male  512
# 2       Vamsi    NaN  345

# %%
d3 = {
    'Name': ['HemaSundar', 'Manish', 'Vamsi',"lavanya"],
     'PIN': [481, 512, 345,56],
    "Color" : ["White","Black","Yellow","Blue"]
}
df2 = pd.DataFrame(d3)
df2
# Out:
#          Name  PIN   Color
# 0  HemaSundar  481   White
# 1      Manish  512   Black
# 2       Vamsi  345  Yellow
# 3     lavanya   56    Blue

# %%
pd.concat([df1,df2], axis = 0) # concat at below
# Out:
#          Name Gender  PIN   Color
# 0  HemaSundar   Male  481     NaN
# 1      Manish   Male  512     NaN
# 2       Vamsi    NaN  345     NaN
# 0  HemaSundar    NaN  481   White
# 1      Manish    NaN  512   Black
# 2       Vamsi    NaN  345  Yellow

# %%
pd.concat([df2,df1], axis = 1) # concat side by side
# Out:
#          Name  PIN   Color        Name Gender  PIN
# 0  HemaSundar  481   White  HemaSundar   Male  481
# 1      Manish  512   Black      Manish   Male  512
# 2       Vamsi  345  Yellow       Vamsi    NaN  345

# %%
df1.append(df2) # appended at below
# Out:
#          Name Gender  PIN   Color
# 0  HemaSundar   Male  481     NaN
# 1      Manish   Male  512     NaN
# 2       Vamsi    NaN  345     NaN
# 0  HemaSundar    NaN  481   White
# 1      Manish    NaN  512   Black
# 2       Vamsi    NaN  345  Yellow

# %%
df2.append(df1)
# Out:
#          Name  PIN   Color Gender
# 0  HemaSundar  481   White    NaN
# 1      Manish  512   Black    NaN
# 2       Vamsi  345  Yellow    NaN
# 0  HemaSundar  481     NaN   Male
# 1      Manish  512     NaN   Male
# 2       Vamsi  345     NaN    NaN

# %%
pd.merge(df1,df2) # one single columns # it retuns only common data rom both dataframes
# Out:
#          Name Gender  PIN   Color
# 0  HemaSundar   Male  481   White
# 1      Manish   Male  512   Black
# 2       Vamsi    NaN  345  Yellow

# %%
df1
# Out:
#          Name Gender  PIN
# 0  HemaSundar   Male  481
# 1      Manish   Male  512
# 2       Vamsi    NaN  345

# %%
df2
# Out:
#          Name  PIN   Color
# 0  HemaSundar  481   White
# 1      Manish  512   Black
# 2       Vamsi  345  Yellow
# 3     lavanya   56    Blue

# %%
pd.merge(df2,df1, how= "right")
# Out:
#          Name  PIN   Color Gender
# 0  HemaSundar  481   White   Male
# 1      Manish  512   Black   Male
# 2       Vamsi  345  Yellow    NaN

# %%
pd.merge(df2,df1, how= "left")
# Out:
#          Name  PIN   Color Gender
# 0  HemaSundar  481   White   Male
# 1      Manish  512   Black   Male
# 2       Vamsi  345  Yellow    NaN
# 3     lavanya   56    Blue    NaN

# %%
pd.merge(df2,df1,how = "outer") # union - all
# Out:
#          Name  PIN   Color Gender
# 0  HemaSundar  481   White   Male
# 1      Manish  512   Black   Male
# 2       Vamsi  345  Yellow    NaN
# 3     lavanya   56    Blue    NaN

# %%
pd.merge(df2,df1,how = "inner")  # intersection - common
# Out:
#          Name  PIN   Color Gender
# 0  HemaSundar  481   White   Male
# 1      Manish  512   Black   Male
# 2       Vamsi  345  Yellow    NaN

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
#         * right: use only keys from right frame, similar to a SQL right outer join;
#           preserve key order.
#         * outer: use union of keys from both frames, similar to a SQL full outer
#           join; sort keys lexicographically.
#         * inner: use intersection of keys from both frames, similar to a SQL inner
#           join; preserve the order of the left keys.
#     on : label or list
#         Column or index level names to join on. These must be found in both
#         DataFrames. If `on` is None and not merging on indexes then this defaults
#         to the intersection of the columns in both DataFrames.
#     left_on : label or list, or array-like
#         Column or index level names to join on in the left DataFrame. Can also
#         be an array or list of arrays of the length of the left DataFrame.
#         These arrays are treated as if they are columns.
#     right_on : label or list, or array-like
#         Column or index level names to join on in the right DataFrame. Can also
#         be an array or list of arrays of the length of the right DataFrame.
#         These arrays are treated as if they are columns.
#     left_index : bool, default False
#         Use the index from the left DataFrame as the join key(s). If it is a
#         MultiIndex, the number of keys in the other DataFrame (either the index
#         or a number of columns) must match the number of levels.
#     right_index : bool, default False
#         Use the index from the right DataFrame as the join key. Same caveats as
#         left_index.
#     sort : bool, default False
#         Sort the join keys lexicographically in the result DataFrame. If False,
#         the order of the join keys depends on the join type (how keyword).
#     suffixes : tuple of (str, str), default ('_x', '_y')
#         Suffix to apply to overlapping column names in the left and right
#         side, respectively. To raise an exception on overlapping columns use
#         (False, False).
#     copy : bool, default True
#         If False, avoid copy if possible.
#     indicator : bool or str, default False
#         If True, adds a column to output DataFrame called "_merge" with
#         information on the source of each row.
#         If string, column with information on source of each row will be added to
#         output DataFrame, and column will be named value of string.
#         Information column is Categorical-type and takes on a value of "left_only"
#         for observations whose merge key only appears in 'left' DataFrame,
#         "right_only" for observations whose merge key only appears in 'right'
#         DataFrame, and "both" if the observation's merge key is found in both.
#
#     validate : str, optional
#         If specified, checks if merge is of specified type.
#
#         * "one_to_one" or "1:1": check if merge keys are unique in both
#           left and right datasets.
#         * "one_to_many" or "1:m": check if merge keys are unique in left
#           dataset.
#         * "many_to_one" or "m:1": check if merge keys are unique in right
#           dataset.
#         * "many_to_many" or "m:m": allowed, but does not result in checks.
#
#         .. versionadded:: 0.21.0
#
#     Returns
#     -------
#     DataFrame
#         A DataFrame of the two merged objects.
#
#     See Also
#     --------
#     merge_ordered : Merge with optional filling/interpolation.
#     merge_asof : Merge on nearest keys.
#     DataFrame.join : Similar method using indices.
#
#     Notes
#     -----
#     Support for specifying index levels as the `on`, `left_on`, and
#     `right_on` parameters was added in version 0.23.0
#     Support for merging named Series objects was added in version 0.24.0
#
#     Examples
#     --------
#
#     >>> df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
#     ...                     'value': [1, 2, 3, 5]})
#     >>> df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
#     ...                     'value': [5, 6, 7, 8]})
#     >>> df1
#         lkey value
#     0   foo      1
#     1   bar      2
#     2   baz      3
#     3   foo      5
#     >>> df2
#         rkey value
#     0   foo      5
#     1   bar      6
#     2   baz      7
#     3   foo      8
#
#     Merge df1 and df2 on the lkey and rkey columns. The value columns have
#     the default suffixes, _x and _y, appended.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey')
#       lkey  value_x rkey  value_y
#     0  foo        1  foo        5
#     1  foo        1  foo        8
#     2  foo        5  foo        5
#     3  foo        5  foo        8
#     4  bar        2  bar        6
#     5  baz        3  baz        7
#
#     Merge DataFrames df1 and df2 with specified left and right suffixes
#     appended to any overlapping columns.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey',
#     ...           suffixes=('_left', '_right'))
#       lkey  value_left rkey  value_right
#     0  foo           1  foo            5
#     1  foo           1  foo            8
#     2  foo           5  foo            5
#     3  foo           5  foo            8
#     4  bar           2  bar            6
#     5  baz           3  baz            7
#
#     Merge DataFrames df1 and df2, but raise an exception if the DataFrames have
#     any overlapping columns.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
#     Traceback (most recent call last):
#     ...
#     ValueError: columns overlap but no suffix specified:
#         Index(['value'], dtype='object')

# %% [markdown]
# # Filtering

# %%
data
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# ..     ...             ...                                     ...
# 40      41   AP19110010131                         Anishita Kakani
# 65      66   AP19110010230                     Akkineni Sohith Sai
# 66      67   AP19110010230                     Akkineni Sohith Sai
# 7        8   AP19110010013                      Addepalli Srilekha
# 25      26   AP19110010090                          Abhinav Challa
#
#                               Email   Mobile No
# 91        yogithagoli1702@gmail.com  9701802216
# 105     umasankaryelchuri@gmail.com  9666961872
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 35          akhilbabu3838@gmail.com  9121536598
# ..                              ...         ...
# 40              anishitak@gmail.com  9399939996
# 65   saiakkinenisohith312@gmail.com  7032338671
# 66   saiakkinenisohith312@gmail.com  7032338671
# 7             serevalli12@gmail.com  8688225663
# 25          abhinavch3011@gmail.com  9182522042
#
# [145 rows x 5 columns]

# %%
data.iloc[100]
# Out:
# S.No.                                    137
# Registration Id                AP19110020035
# Name                          Jahnavi Mangam
# Email              jahnavimangam17@gmail.com
# Mobile No                         9948274445
# Name: 136, dtype: object

# %%
data[data["S.No."] > 100]           # data Masking
# Out:
#      S.No. Registration Id                                    Name  \
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 127    128   AP19110010519                                 V Akhil
# 144    145    AP1911010183                  Tiwari Dharmesh Sharma
# 118    119   AP19110010463                    Thatha Naga Jayasree
# 115    116   AP19110010449                     Sumana Bandarupalli
# 116    117   AP19110010449                     Sumana Bandarupalli
# 113    114   AP19110010431                      Satya Mani Syam. D
# 141    142   AP19110020077                           Saptharishi.D
# 142    143   AP19110020077                     Saptharishi Reddy.D
# 133    134   AP19110010543                             Sai Keerthi
# 124    125   AP19110010510                  Rishitha Reddy Maryada
# 114    115   AP19110010441                      Rishitha Chilukuri
# 122    123   AP19110010500              Relangi Babi Vamsi Krishna
# 137    138   AP19110020036                  Pavan Mohan Neelamraju
# 134    135   AP19110010549                          P.Ruthikvenkat
# 117    118   AP19110010459                              P. Dheeraj
# 130    131   AP19110010523                        Oruganti Aravind
# 132    133   AP19110010542                            Nitesh Kumar
# 112    113   AP19110010430                      Mothukuri Noushika
# 129    130   AP19110010521                           Manish Guduri
# 100    101   AP19110010382                            Manasa Nunna
# 138    139   AP19110020041               Manam Keerthi Pavan Kumar
# 139    140   AP19110020041               Manam Keerthi Pavan Kumar
# 102    103   AP19110010388                         Mahesh Valavala
# 140    141   AP19110020052                                  Mahesh
# 135    136   AP19110010553                     Mahalakshmi Damarla
# 106    107   AP19110010399                   Kotapati Shyam Sundar
# 108    109   AP19110010414                   Kondaveeti Anugna Sai
# 104    105   AP19110010392                   Koliparthi Durgavamsi
# 110    111   AP19110010425                    Katakam Akshay Reddy
# 143    144   AP19110020106               Karnatapu Sri Sai Dhanush
# 126    127   AP19110010515                    Jaya Harshith Ambati
# 136    137   AP19110020035                          Jahnavi Mangam
# 103    104   AP19110010390                       J.Manoj Mahanandi
# 125    126   AP19110010511                          Ishita Agrawal
# 131    132   AP19110010534                      Greeshma Kommineni
# 109    110   AP19110010421            Godavarthi Venkata Narasamma
# 120    121   AP19110010481                      E Hemasundar Yadav
# 111    112   AP19110010428                 Dandibhotla Bala Pranav
# 101    102   AP19110010386                        Damarla Ramadevi
# 119    120   AP19110010470                        D.Lavanya Sujana
# 123    124   AP19110010504                      D Tarun Venkat Sai
# 107    108   AP19110010402                      Chandanam Tanmayee
# 128    129   AP19110010520                Chandaluri Snigdha Setty
# 121    122   AP19110010495                      Batchu Raja Nithin
#
#                                    Email   Mobile No
# 105          umasankaryelchuri@gmail.com  9666961872
# 127                 akhil0805v@gmail.com  9347657721
# 144     dharmeshsharma17122002@gmail.com  9704043879
# 118             thathajayasree@gmail.com  9110727521
# 115         sumanabandarupalli@gmail.com  8074434915
# 116         sumanabandarupalli@gmail.com  8074434915
# 113              syamdontula99@gmail.com  9133626880
# 141                 0123saptha@gmail.com  9000666305
# 142                 0123saptha@gmail.com  9000666305
# 133                kittu601399@gmail.com  8500074169
# 124       rishithareddymaryada@gmail.com  9059728048
# 114  chilukuririshithareddy123@gmail.com  9398735959
# 122        krishna.relangi3672@gmail.com  9704863652
# 137               npavanmohan3@gmail.com  9603853877
# 134         ruthikpavanagundla@gmail.com  8599901333
# 117             ram.dheer.ds.5@gmail.com  8688288702
# 130                oravindchow@gmail.com  8688216404
# 132         bittusoni753378446@gmail.com  9113432950
# 112                 noushika15@gmail.com  9533234666
# 129               gudurimanish@gmail.com  8247621148
# 100          lakshmimanasa1512@gmail.com  9441271128
# 138         pavankumarmanam846@gmail.com  8639015559
# 139         pavankumarmanam846@gmail.com  8639015559
# 102         maheshvalavala0388@gmail.com  9963039933
# 140             mahesh2001.sis@gmail.com  7989651824
# 135        mahalakshmidamarla6@gmail.com  7901097444
# 106        shyamsundarkotapati@gmail.com  8688733035
# 108             anugna99sai567@gmail.com  8179327875
# 104             durga.vamsi.co@gmail.com  9014235991
# 110         akshayreddykatakam@gmail.com  7569891759
# 143       dhanushkarnatapu1440@gmail.com  9398018626
# 126              jayaharshith7@gmail.com  9182211321
# 136            jahnavimangam17@gmail.com  9948274445
# 103            manojmahanandi2@gmail.com  8688700904
# 125           ishitaagrawal909@gmail.com  7489480680
# 131              kgreeshma2002@gmail.com  9494122412
# 109           venky.chinna2312@gmail.com  8688532726
# 120         eddalahemasundar32@gmail.com  9618456239
# 111              balapranav777@gmail.com  8688879473
# 101                    drd9869@gmail.com  9493451234
# 119        lavanyasujanadamera@gmail.com  9948153456
# 123              tarundamarla9@gmail.com  7997703595
# 107            tanmayechandana@gmail.com  9985891293
# 128            snigdharupesh16@gmail.com  9754756789
# 121              nitinbatchu15@gmail.com  8008867604

# %%
data[data["Mobile No"] > 9000000000]
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# 6        7   AP19110010011           V Naga Sai Aditya Gandavarapu
# 127    128   AP19110010519                                 V Akhil
# ..     ...             ...                                     ...
# 51      52   AP19110010174                     Boyapati Sai Venkat
# 9       10   AP19110010015                 Boorlagadda Sai Subhang
# 34      35   AP19110010116           Bharath Kumar Reddy Sanikommu
# 40      41   AP19110010131                         Anishita Kakani
# 25      26   AP19110010090                          Abhinav Challa
#
#                              Email   Mobile No
# 91       yogithagoli1702@gmail.com  9701802216
# 105    umasankaryelchuri@gmail.com  9666961872
# 35         akhilbabu3838@gmail.com  9121536598
# 6    adityagandavarapu66@gmail.com  9110333929
# 127           akhil0805v@gmail.com  9347657721
# ..                             ...         ...
# 51          svboyapati24@gmail.com  9182708804
# 9           subhang51011@gmail.com  9014273040
# 34      bharathsanikommu@gmail.com  9110722944
# 40             anishitak@gmail.com  9399939996
# 25         abhinavch3011@gmail.com  9182522042
#
# [76 rows x 5 columns]

# %%
# want to access the records having moblie no starts with 9 and 8 
data[data["Mobile No"] > 8000000000]
# Out:
#      S.No. Registration Id                                    Name  \
# 91      92   AP19110010320                            Yogitha Goli
# 105    106   AP19110010395  Yelchuri Uma Sankar Phani Kumar Guptha
# 82      83   AP19110010296                  Yaminibhargavi Alapati
# 83      84   AP19110010296                  Yaminibhargavi Alapati
# 35      36   AP19110010118                Vankayalapati Akhil Babu
# ..     ...             ...                                     ...
# 26      27   AP19110010092                              B.C Amulya
# 67      68   AP19110010234                    Attuluri Prudhvi Raj
# 40      41   AP19110010131                         Anishita Kakani
# 7        8   AP19110010013                      Addepalli Srilekha
# 25      26   AP19110010090                          Abhinav Challa
#
#                               Email   Mobile No
# 91        yogithagoli1702@gmail.com  9701802216
# 105     umasankaryelchuri@gmail.com  9666961872
# 82   munnychowdaryalapati@gmail.com  8639173919
# 83   munnychowdaryalapati@gmail.com  8639173919
# 35          akhilbabu3838@gmail.com  9121536598
# ..                              ...         ...
# 26      chinmayeamulyasai@gmail.com  8099776689
# 67        prudhviattuluri@gmail.com  8500016935
# 40              anishitak@gmail.com  9399939996
# 7             serevalli12@gmail.com  8688225663
# 25          abhinavch3011@gmail.com  9182522042
#
# [122 rows x 5 columns]

# %%
# access the records having moblie no starts with 7 and 8 
data[7000000000 < data["Mobile No"] < 9000000000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-181-4b1ba1211fe9> in <module>
#       1 # access the records having moblie no starts with 7 and 8
# ----> 2 data[7000000000 < data["Mobile No"] < 9000000000]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data[data["Mobile No"]>7000000000]
data[data["Mobile No"]<9000000000]
# Out:
#     S.No. Registration Id                          Name  \
# 82     83   AP19110010296        Yaminibhargavi Alapati
# 83     84   AP19110010296        Yaminibhargavi Alapati
# 52     53   AP19110010175      Vangala Bhargava Anirudh
# 98     99   AP19110010374               Vaishnavi Datla
# 58     59   AP19110010212  Tiyyagura Durga Prasad Reddy
# ..    ...             ...                           ...
# 67     68   AP19110010234          Attuluri Prudhvi Raj
# 93     94   AP19110010340            Anjana Nallanagula
# 65     66   AP19110010230           Akkineni Sohith Sai
# 66     67   AP19110010230           Akkineni Sohith Sai
# 7       8   AP19110010013            Addepalli Srilekha
#
#                              Email   Mobile No
# 82  munnychowdaryalapati@gmail.com  8639173919
# 83  munnychowdaryalapati@gmail.com  8639173919
# 52         anirudhroy241@gmail.com  8886862576
# 98      vaishnavivarma87@gmail.com  8790988244
# 58      tdurgaprasad2002@gmail.com  7981821182
# ..                             ...         ...
# 67       prudhviattuluri@gmail.com  8500016935
# 93    anjana.nallanagula@gmail.com  7981935617
# 65  saiakkinenisohith312@gmail.com  7032338671
# 66  saiakkinenisohith312@gmail.com  7032338671
# 7            serevalli12@gmail.com  8688225663
#
# [69 rows x 5 columns]

# %%
data[(data["Mobile No"] > 7000000000) & (data["Mobile No"] < 9000000000)]
# Out:
#     S.No. Registration Id                          Name  \
# 82     83   AP19110010296        Yaminibhargavi Alapati
# 83     84   AP19110010296        Yaminibhargavi Alapati
# 52     53   AP19110010175      Vangala Bhargava Anirudh
# 98     99   AP19110010374               Vaishnavi Datla
# 58     59   AP19110010212  Tiyyagura Durga Prasad Reddy
# ..    ...             ...                           ...
# 67     68   AP19110010234          Attuluri Prudhvi Raj
# 93     94   AP19110010340            Anjana Nallanagula
# 65     66   AP19110010230           Akkineni Sohith Sai
# 66     67   AP19110010230           Akkineni Sohith Sai
# 7       8   AP19110010013            Addepalli Srilekha
#
#                              Email   Mobile No
# 82  munnychowdaryalapati@gmail.com  8639173919
# 83  munnychowdaryalapati@gmail.com  8639173919
# 52         anirudhroy241@gmail.com  8886862576
# 98      vaishnavivarma87@gmail.com  8790988244
# 58      tdurgaprasad2002@gmail.com  7981821182
# ..                             ...         ...
# 67       prudhviattuluri@gmail.com  8500016935
# 93    anjana.nallanagula@gmail.com  7981935617
# 65  saiakkinenisohith312@gmail.com  7032338671
# 66  saiakkinenisohith312@gmail.com  7032338671
# 7            serevalli12@gmail.com  8688225663
#
# [69 rows x 5 columns]

# %%
data2 = data.copy()
data2['Mobile No'] = data2['Mobile No'].astype(str)
m_num = input("Enter the number, to find the numbers starts with that number: ")
series = data2['Mobile No'].str.startswith(m_num)
data2[series]
# Out:
# Enter the number, to find the numbers starts with that number: 7
#      S.No. Registration Id                          Name  \
# 58      59   AP19110010212  Tiyyagura Durga Prasad Reddy
# 0        1   AP19110010001   Tata Lakshmi Durga Likhitha
# 64      65   AP19110010229               R. Hasitha Sree
# 37      38   AP19110010126                R . Uday Kiran
# 94      95   AP19110010346                  Pushpa Latha
# 44      45   AP19110010160              Mullapudi Venkat
# 72      73   AP19110010249                   Mohit Kumar
# 140    141   AP19110020052                        Mahesh
# 135    136   AP19110010553           Mahalakshmi Damarla
# 23      24   AP19110010080                       M.Tarun
# 33      34   AP19110010112          Lakkireddy Harshitha
# 86      87   AP19110010308             Kommineni Sahithi
# 110    111   AP19110010425          Katakam Akshay Reddy
# 73      74   AP19110010252                   K Sriharsha
# 4        5   AP19110010007    Jaya Ganesh Kumar Gudipati
# 125    126   AP19110010511                Ishita Agrawal
# 71      72   AP19110010246                  Ghanta Jaiya
# 47      48   AP19110010166             G.B.N.V.S.Abhinav
# 123    124   AP19110010504            D Tarun Venkat Sai
# 1        2   AP19110010003             Bhuvana Venigalla
# 93      94   AP19110010340            Anjana Nallanagula
# 65      66   AP19110010230           Akkineni Sohith Sai
# 66      67   AP19110010230           Akkineni Sohith Sai
#
#                               Email   Mobile No
# 58       tdurgaprasad2002@gmail.com  7981821182
# 0          tatalikhitha01@gmail.com  7287982736
# 64        rhasithasree123@gmail.com  7337050642
# 37      udaykiranramaraju@gmail.com  7780273060
# 94      pushpalathaavvaru@gmail.com  7995694959
# 44   Venkatmullapudi14300@gmail.com  7032567895
# 72    mohitkumar.projects@gmail.com  7281809313
# 140        mahesh2001.sis@gmail.com  7989651824
# 135   mahalakshmidamarla6@gmail.com  7901097444
# 23       tarunchowdary001@gmail.com  7337433099
# 33    harshithalakkireddy@gmail.com  7093566384
# 86    sahithi.kommineni32@gmail.com  7997045446
# 110    akshayreddykatakam@gmail.com  7569891759
# 73            bsriharsh48@gmail.com  7075855001
# 4        jayaganeshkumarg@gmail.com  7330654249
# 125      ishitaagrawal909@gmail.com  7489480680
# 71          ghantajaiya12@gmail.com  7013144227
# 47    saiabhinavgarlapati@gmail.com  7207723457
# 123         tarundamarla9@gmail.com  7997703595
# 1        venigallabhuvana@gmail.com  7989023905
# 93     anjana.nallanagula@gmail.com  7981935617
# 65   saiakkinenisohith312@gmail.com  7032338671
# 66   saiakkinenisohith312@gmail.com  7032338671
